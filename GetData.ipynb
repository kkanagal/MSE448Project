# %%
import sys
import simulator as sim
import numpy as np
import datetime as dt
import pandas as pd

SEC = 1000000
MIN = 60 * SEC
DOLLAR = 1000000

###############################################################################
# Store daily book data in a .txt file
###############################################################################

DATA_PATH = "data/"

class StoreDayData(object):
    
    def __init__(self, session, date, ticker, 
                 num_levels = 5,
                 start_time = sim.string_to_micro("09:30"), 
                 end_time = sim.string_to_micro("15:30")):
        self.session = session
        self.date = date
        self.ticker = ticker
        self.start_time = start_time
        self.end_time = end_time
    
        self.num = (self.end_time - self.start_time) / MIN
        self.num_levels = num_levels
        self.time_index = 0
        
        # book_data is dict
        # keys: ticker
        #values: am ndarray with columns
        #     0: time
        #     1: average price (to obtain the output signal to feed the SVM)
        #   2-6: queue size of ask levels 1-5
        #  7-11: queue size of bid levels 1-5
        self.book_data = {}
        
        for sym_it in self.ticker:
            self.session.subscribe_ticker_all_feeds(sym_it)
            self.book_data[sym_it] = np.empty(shape = [self.num, 2 * self.num_levels + 2])
        for i in range(self.num):
            self.session.add_timer(self.start_time + i * MIN, self.timer_getdata_callback)    
        
        
    def timer_getdata_callback(self, time):
        #print "hihi, it is now {0}".format(sim.micro_to_time(time))
        for sym_it in self.ticker:
            book = self.session.get_book_levels(sym_it, nlevels = self.num_levels)
            #print book
            bids = book["bids"]
            asks = book["asks"]
        
            self.book_data[sym_it][self.time_index, 0] = time
            best_bid, best_ask = self.session.get_inside_market(sym_it)
            self.book_data[sym_it][self.time_index, 1] = (bids[0]["price"] + asks[0]["price"]) / 2.0 / DOLLAR

            for i in range(self.num_levels):
                #print i
                self.book_data[sym_it][self.time_index, i + 2] = asks[i]["size"]
                self.book_data[sym_it][self.time_index, i + 7] = bids[i]["size"]
        #print "current is {0}, max is {1}".format(self.time_index, self.num)
        self.time_index += 1
            
            
    def end(self):
        time = self.session.current_time()
        print "DONDONDON: it's now {0}".format(sim.micro_to_time(time))
        for sym_it in self.ticker:
            filename = "{0}{1}_{2}_bookdata.txt".format(DATA_PATH, sym_it, self.date)
            np.savetxt(filename, self.book_data[sym_it], newline = "\n")
            print "Saved to {0}".format(filename)
        return
    
###############################################################################
# Read from book data file and convert it to feedable SVM data
###############################################################################
    
    
def treat_data(ticker, date, threshold = 0.01):
    raw_filename = "{0}{1}_{2}_bookdata.txt".format(DATA_PATH, ticker, date) 
    raw_data = np.loadtxt(raw_filename)
    num_data = raw_data.shape[0]
    num_lvls = (raw_data.shape[1] - 2) / 2
    buildup = [1, 2, 3, 5, 10, 15]
    
    # sig_data is the output signal for the SVM, as a (n, 1) ndarray
    sig_data = np.empty(shape = [num_data - 15, 1], dtype=np.int16)
    # obp_data is the SVM input as a (n, 6 * num_lvls) ndarray where
    # OBP(t, l) = obp_data[ , t*num_lvls + + l]
    obp_data = np.empty(shape = [num_data - 15, 6 * num_lvls])
    
    for i in range(15, num_data):
        #price_change = (raw_data[i, 1] - raw_data[i - 1, 1]) / raw_data[i - 1, 1]
        price_change = raw_data[i, 1] - raw_data[i - 1, 1]
        if price_change < -threshold:
            sig_data[i-15, 0] = -1
        elif price_change > threshold:
            sig_data[i-15, 0] = 1
        else:
            sig_data[i-15, 0] = 0
            
        for t in range(len(buildup)):
            for j in range(num_lvls):
                obp_data[i-15, t*num_lvls + j] = np.sum(raw_data[(i-buildup[t]):(i+1), 7:(j+8)]) / \
                    np.sum(raw_data[(i-buildup[t]):(i+1), 2:(j+3)])
                            
    obp_filename = "{0}{1}_{2}_obp.txt".format(DATA_PATH, ticker, date)
    sig_filename = "{0}{1}_{2}_sig.txt".format(DATA_PATH, ticker, date)
    np.savetxt(obp_filename, obp_data, newline = "\n")
    np.savetxt(sig_filename, sig_data, fmt="%d", newline = "\n")
    print "Saved to {0}".format(obp_filename)
    
#date = "20150121"
start = dt.date( 2015, 1, 21 )
end = dt.date( 2015, 4, 12 )
days = pd.bdate_range(start - dt.timedelta(days=10), end)
to_remove = ["20150119", "20150216", "20150403", "20150525", "20150703", "20150824", "20151126", "20151225",
             "20160101","20160118","20160215","20160325","20160530","20160704","20160905","20161124","20161226",
             "20170102","20170116","20170220","20170414","20170518"]
#days = days[!days['date'].isin(to_remove)]
market = ["IVV"]
basic_large = ["PG", "UN", "UL", "BHP", "DOW"]
basic_mid = ["STLD", "FBHS", "SQM", "WLK", "SEE"]
tech_large = ["AAPL", "GOOG", "MSFT", "FB", "ORCL"]
tech_mid = ["IPG", "CDNS", "DOX", "VRSN", "FLEX"]
finance_large = ["JPM", "WFC", "BAC", "HSBC", "C"]
finance_mid = ["ALLY", "CBOE", "WF", "ETFC", "AVAL"]
health_large = ["JNJ", "NVS", "PFE", "MRK", "UNH"]
health_mid = ["SGEN", "VAR", "TFX", "ALKS", "JAZZ"]
energy_large = ["XOM", "GE", "CVX", "TOT", "PTR"]
energy_mid = ["XEC", "TSO", "YPF", "EQT", "PE"]
symbols = basic_large + tech_large + finance_large + health_large + energy_large + market
print symbols
start_time = sim.string_to_micro("9:30")
end_time = sim.string_to_micro("15:30")

#simul_storedata = sim.Simulator(StoreDayData)
#simul_storedata.run("20150120", symbols, num_levels = 5, start_time = start_time, end_time = end_time)
for day in days:
    training_date = '{:%Y%m%d}'.format(day.date())
    print training_date
    if training_date in to_remove:
        continue
    simul_storedata = sim.Simulator(StoreDayData)
    simul_storedata.run(training_date, symbols, num_levels = 5)

    
#for sym_it in symbols:
    #treat_data(sym_it, training_date, threshold = 0.04)
# Out:
# ['PG', 'UN', 'UL', 'BHP', 'DOW', 'AAPL', 'GOOG', 'MSFT', 'FB', 'ORCL', 'JPM', 'WFC', 'BAC', 'HSBC', 'C', 'JNJ', 'NVS', 'PFE', 'MRK', 'UNH', 'XOM', 'GE', 'CVX', 'TOT', 'PTR', 'IVV']
# 20150112
# DONDONDON: it's now 18:04:59.753213
# Saved to data/PG_20150112_bookdata.txt
# Saved to data/UN_20150112_bookdata.txt
# Saved to data/UL_20150112_bookdata.txt
# Saved to data/BHP_20150112_bookdata.txt
# Saved to data/DOW_20150112_bookdata.txt
# Saved to data/AAPL_20150112_bookdata.txt
# Saved to data/GOOG_20150112_bookdata.txt
# Saved to data/MSFT_20150112_bookdata.txt
# Saved to data/FB_20150112_bookdata.txt
# Saved to data/ORCL_20150112_bookdata.txt
# Saved to data/JPM_20150112_bookdata.txt
# Saved to data/WFC_20150112_bookdata.txt
# Saved to data/BAC_20150112_bookdata.txt
# Saved to data/HSBC_20150112_bookdata.txt
# Saved to data/C_20150112_bookdata.txt
# Saved to data/JNJ_20150112_bookdata.txt
# Saved to data/NVS_20150112_bookdata.txt
# Saved to data/PFE_20150112_bookdata.txt
# Saved to data/MRK_20150112_bookdata.txt
# Saved to data/UNH_20150112_bookdata.txt
# Saved to data/XOM_20150112_bookdata.txt
# Saved to data/GE_20150112_bookdata.txt
# Saved to data/CVX_20150112_bookdata.txt
# Saved to data/TOT_20150112_bookdata.txt
# Saved to data/PTR_20150112_bookdata.txt
# Saved to data/IVV_20150112_bookdata.txt
# 20150113
# DONDONDON: it's now 18:04:56.328144
# Saved to data/PG_20150113_bookdata.txt
# Saved to data/UN_20150113_bookdata.txt
# Saved to data/UL_20150113_bookdata.txt
# Saved to data/BHP_20150113_bookdata.txt
# Saved to data/DOW_20150113_bookdata.txt
# Saved to data/AAPL_20150113_bookdata.txt
# Saved to data/GOOG_20150113_bookdata.txt
# Saved to data/MSFT_20150113_bookdata.txt
# Saved to data/FB_20150113_bookdata.txt
# Saved to data/ORCL_20150113_bookdata.txt
# Saved to data/JPM_20150113_bookdata.txt
# Saved to data/WFC_20150113_bookdata.txt
# Saved to data/BAC_20150113_bookdata.txt
# Saved to data/HSBC_20150113_bookdata.txt
# Saved to data/C_20150113_bookdata.txt
# Saved to data/JNJ_20150113_bookdata.txt
# Saved to data/NVS_20150113_bookdata.txt
# Saved to data/PFE_20150113_bookdata.txt
# Saved to data/MRK_20150113_bookdata.txt
# Saved to data/UNH_20150113_bookdata.txt
# Saved to data/XOM_20150113_bookdata.txt
# Saved to data/GE_20150113_bookdata.txt
# Saved to data/CVX_20150113_bookdata.txt
# Saved to data/TOT_20150113_bookdata.txt
# Saved to data/PTR_20150113_bookdata.txt
# Saved to data/IVV_20150113_bookdata.txt
# 20150114
# DONDONDON: it's now 18:04:59.736973
# Saved to data/PG_20150114_bookdata.txt
# Saved to data/UN_20150114_bookdata.txt
# Saved to data/UL_20150114_bookdata.txt
# Saved to data/BHP_20150114_bookdata.txt
# Saved to data/DOW_20150114_bookdata.txt
# Saved to data/AAPL_20150114_bookdata.txt
# Saved to data/GOOG_20150114_bookdata.txt
# Saved to data/MSFT_20150114_bookdata.txt
# Saved to data/FB_20150114_bookdata.txt
# Saved to data/ORCL_20150114_bookdata.txt
# Saved to data/JPM_20150114_bookdata.txt
# Saved to data/WFC_20150114_bookdata.txt
# Saved to data/BAC_20150114_bookdata.txt
# Saved to data/HSBC_20150114_bookdata.txt
# Saved to data/C_20150114_bookdata.txt
# Saved to data/JNJ_20150114_bookdata.txt
# Saved to data/NVS_20150114_bookdata.txt
# Saved to data/PFE_20150114_bookdata.txt
# Saved to data/MRK_20150114_bookdata.txt
# Saved to data/UNH_20150114_bookdata.txt
# Saved to data/XOM_20150114_bookdata.txt
# Saved to data/GE_20150114_bookdata.txt
# Saved to data/CVX_20150114_bookdata.txt
# Saved to data/TOT_20150114_bookdata.txt
# Saved to data/PTR_20150114_bookdata.txt
# Saved to data/IVV_20150114_bookdata.txt
# 20150115
# DONDONDON: it's now 18:04:59.401383
# Saved to data/PG_20150115_bookdata.txt
# Saved to data/UN_20150115_bookdata.txt
# Saved to data/UL_20150115_bookdata.txt
# Saved to data/BHP_20150115_bookdata.txt
# Saved to data/DOW_20150115_bookdata.txt
# Saved to data/AAPL_20150115_bookdata.txt
# Saved to data/GOOG_20150115_bookdata.txt
# Saved to data/MSFT_20150115_bookdata.txt
# Saved to data/FB_20150115_bookdata.txt
# Saved to data/ORCL_20150115_bookdata.txt
# Saved to data/JPM_20150115_bookdata.txt
# Saved to data/WFC_20150115_bookdata.txt
# Saved to data/BAC_20150115_bookdata.txt
# Saved to data/HSBC_20150115_bookdata.txt
# Saved to data/C_20150115_bookdata.txt
# Saved to data/JNJ_20150115_bookdata.txt
# Saved to data/NVS_20150115_bookdata.txt
# Saved to data/PFE_20150115_bookdata.txt
# Saved to data/MRK_20150115_bookdata.txt
# Saved to data/UNH_20150115_bookdata.txt
# Saved to data/XOM_20150115_bookdata.txt
# Saved to data/GE_20150115_bookdata.txt
# Saved to data/CVX_20150115_bookdata.txt
# Saved to data/TOT_20150115_bookdata.txt
# Saved to data/PTR_20150115_bookdata.txt
# Saved to data/IVV_20150115_bookdata.txt
# 20150116
# DONDONDON: it's now 18:04:50.966624
# Saved to data/PG_20150116_bookdata.txt
# Saved to data/UN_20150116_bookdata.txt
# Saved to data/UL_20150116_bookdata.txt
# Saved to data/BHP_20150116_bookdata.txt
# Saved to data/DOW_20150116_bookdata.txt
# Saved to data/AAPL_20150116_bookdata.txt
# Saved to data/GOOG_20150116_bookdata.txt
# Saved to data/MSFT_20150116_bookdata.txt
# Saved to data/FB_20150116_bookdata.txt
# Saved to data/ORCL_20150116_bookdata.txt
# Saved to data/JPM_20150116_bookdata.txt
# Saved to data/WFC_20150116_bookdata.txt
# Saved to data/BAC_20150116_bookdata.txt
# Saved to data/HSBC_20150116_bookdata.txt
# Saved to data/C_20150116_bookdata.txt
# Saved to data/JNJ_20150116_bookdata.txt
# Saved to data/NVS_20150116_bookdata.txt
# Saved to data/PFE_20150116_bookdata.txt
# Saved to data/MRK_20150116_bookdata.txt
# Saved to data/UNH_20150116_bookdata.txt
# Saved to data/XOM_20150116_bookdata.txt
# Saved to data/GE_20150116_bookdata.txt
# Saved to data/CVX_20150116_bookdata.txt
# Saved to data/TOT_20150116_bookdata.txt
# Saved to data/PTR_20150116_bookdata.txt
# Saved to data/IVV_20150116_bookdata.txt
# 20150119
# 20150120
# DONDONDON: it's now 18:04:58.513437
# Saved to data/PG_20150120_bookdata.txt
# Saved to data/UN_20150120_bookdata.txt
# Saved to data/UL_20150120_bookdata.txt
# Saved to data/BHP_20150120_bookdata.txt
# Saved to data/DOW_20150120_bookdata.txt
# Saved to data/AAPL_20150120_bookdata.txt
# Saved to data/GOOG_20150120_bookdata.txt
# Saved to data/MSFT_20150120_bookdata.txt
# Saved to data/FB_20150120_bookdata.txt
# Saved to data/ORCL_20150120_bookdata.txt
# Saved to data/JPM_20150120_bookdata.txt
# Saved to data/WFC_20150120_bookdata.txt
# Saved to data/BAC_20150120_bookdata.txt
# Saved to data/HSBC_20150120_bookdata.txt
# Saved to data/C_20150120_bookdata.txt
# Saved to data/JNJ_20150120_bookdata.txt
# Saved to data/NVS_20150120_bookdata.txt
# Saved to data/PFE_20150120_bookdata.txt
# Saved to data/MRK_20150120_bookdata.txt
# Saved to data/UNH_20150120_bookdata.txt
# Saved to data/XOM_20150120_bookdata.txt
# Saved to data/GE_20150120_bookdata.txt
# Saved to data/CVX_20150120_bookdata.txt
# Saved to data/TOT_20150120_bookdata.txt
# Saved to data/PTR_20150120_bookdata.txt
# Saved to data/IVV_20150120_bookdata.txt
# 20150121
# DONDONDON: it's now 18:05:00.124348
# Saved to data/PG_20150121_bookdata.txt
# Saved to data/UN_20150121_bookdata.txt
# Saved to data/UL_20150121_bookdata.txt
# Saved to data/BHP_20150121_bookdata.txt
# Saved to data/DOW_20150121_bookdata.txt
# Saved to data/AAPL_20150121_bookdata.txt
# Saved to data/GOOG_20150121_bookdata.txt
# Saved to data/MSFT_20150121_bookdata.txt
# Saved to data/FB_20150121_bookdata.txt
# Saved to data/ORCL_20150121_bookdata.txt
# Saved to data/JPM_20150121_bookdata.txt
# Saved to data/WFC_20150121_bookdata.txt
# Saved to data/BAC_20150121_bookdata.txt
# Saved to data/HSBC_20150121_bookdata.txt
# Saved to data/C_20150121_bookdata.txt
# Saved to data/JNJ_20150121_bookdata.txt
# Saved to data/NVS_20150121_bookdata.txt
# Saved to data/PFE_20150121_bookdata.txt
# Saved to data/MRK_20150121_bookdata.txt
# Saved to data/UNH_20150121_bookdata.txt
# Saved to data/XOM_20150121_bookdata.txt
# Saved to data/GE_20150121_bookdata.txt
# Saved to data/CVX_20150121_bookdata.txt
# Saved to data/TOT_20150121_bookdata.txt
# Saved to data/PTR_20150121_bookdata.txt
# Saved to data/IVV_20150121_bookdata.txt
# 20150122
# DONDONDON: it's now 18:04:57.505889
# Saved to data/PG_20150122_bookdata.txt
# Saved to data/UN_20150122_bookdata.txt
# Saved to data/UL_20150122_bookdata.txt
# Saved to data/BHP_20150122_bookdata.txt
# Saved to data/DOW_20150122_bookdata.txt
# Saved to data/AAPL_20150122_bookdata.txt
# Saved to data/GOOG_20150122_bookdata.txt
# Saved to data/MSFT_20150122_bookdata.txt
# Saved to data/FB_20150122_bookdata.txt
# Saved to data/ORCL_20150122_bookdata.txt
# Saved to data/JPM_20150122_bookdata.txt
# Saved to data/WFC_20150122_bookdata.txt
# Saved to data/BAC_20150122_bookdata.txt
# Saved to data/HSBC_20150122_bookdata.txt
# Saved to data/C_20150122_bookdata.txt
# Saved to data/JNJ_20150122_bookdata.txt
# Saved to data/NVS_20150122_bookdata.txt
# Saved to data/PFE_20150122_bookdata.txt
# Saved to data/MRK_20150122_bookdata.txt
# Saved to data/UNH_20150122_bookdata.txt
# Saved to data/XOM_20150122_bookdata.txt
# Saved to data/GE_20150122_bookdata.txt
# Saved to data/CVX_20150122_bookdata.txt
# Saved to data/TOT_20150122_bookdata.txt
# Saved to data/PTR_20150122_bookdata.txt
# Saved to data/IVV_20150122_bookdata.txt
# 20150123
# DONDONDON: it's now 18:04:53.062328
# Saved to data/PG_20150123_bookdata.txt
# Saved to data/UN_20150123_bookdata.txt
# Saved to data/UL_20150123_bookdata.txt
# Saved to data/BHP_20150123_bookdata.txt
# Saved to data/DOW_20150123_bookdata.txt
# Saved to data/AAPL_20150123_bookdata.txt
# Saved to data/GOOG_20150123_bookdata.txt
# Saved to data/MSFT_20150123_bookdata.txt
# Saved to data/FB_20150123_bookdata.txt
# Saved to data/ORCL_20150123_bookdata.txt
# Saved to data/JPM_20150123_bookdata.txt
# Saved to data/WFC_20150123_bookdata.txt
# Saved to data/BAC_20150123_bookdata.txt
# Saved to data/HSBC_20150123_bookdata.txt
# Saved to data/C_20150123_bookdata.txt
# Saved to data/JNJ_20150123_bookdata.txt
# Saved to data/NVS_20150123_bookdata.txt
# Saved to data/PFE_20150123_bookdata.txt
# Saved to data/MRK_20150123_bookdata.txt
# Saved to data/UNH_20150123_bookdata.txt
# Saved to data/XOM_20150123_bookdata.txt
# Saved to data/GE_20150123_bookdata.txt
# Saved to data/CVX_20150123_bookdata.txt
# Saved to data/TOT_20150123_bookdata.txt
# Saved to data/PTR_20150123_bookdata.txt
# Saved to data/IVV_20150123_bookdata.txt
# 20150126
# DONDONDON: it's now 18:04:59.856370
# Saved to data/PG_20150126_bookdata.txt
# Saved to data/UN_20150126_bookdata.txt
# Saved to data/UL_20150126_bookdata.txt
# Saved to data/BHP_20150126_bookdata.txt
# Saved to data/DOW_20150126_bookdata.txt
# Saved to data/AAPL_20150126_bookdata.txt
# Saved to data/GOOG_20150126_bookdata.txt
# Saved to data/MSFT_20150126_bookdata.txt
# Saved to data/FB_20150126_bookdata.txt
# Saved to data/ORCL_20150126_bookdata.txt
# Saved to data/JPM_20150126_bookdata.txt
# Saved to data/WFC_20150126_bookdata.txt
# Saved to data/BAC_20150126_bookdata.txt
# Saved to data/HSBC_20150126_bookdata.txt
# Saved to data/C_20150126_bookdata.txt
# Saved to data/JNJ_20150126_bookdata.txt
# Saved to data/NVS_20150126_bookdata.txt
# Saved to data/PFE_20150126_bookdata.txt
# Saved to data/MRK_20150126_bookdata.txt
# Saved to data/UNH_20150126_bookdata.txt
# Saved to data/XOM_20150126_bookdata.txt
# Saved to data/GE_20150126_bookdata.txt
# Saved to data/CVX_20150126_bookdata.txt
# Saved to data/TOT_20150126_bookdata.txt
# Saved to data/PTR_20150126_bookdata.txt
# Saved to data/IVV_20150126_bookdata.txt
# 20150127
# DONDONDON: it's now 18:05:00.227938
# Saved to data/PG_20150127_bookdata.txt
# Saved to data/UN_20150127_bookdata.txt
# Saved to data/UL_20150127_bookdata.txt
# Saved to data/BHP_20150127_bookdata.txt
# Saved to data/DOW_20150127_bookdata.txt
# Saved to data/AAPL_20150127_bookdata.txt
# Saved to data/GOOG_20150127_bookdata.txt
# Saved to data/MSFT_20150127_bookdata.txt
# Saved to data/FB_20150127_bookdata.txt
# Saved to data/ORCL_20150127_bookdata.txt
# Saved to data/JPM_20150127_bookdata.txt
# Saved to data/WFC_20150127_bookdata.txt
# Saved to data/BAC_20150127_bookdata.txt
# Saved to data/HSBC_20150127_bookdata.txt
# Saved to data/C_20150127_bookdata.txt
# Saved to data/JNJ_20150127_bookdata.txt
# Saved to data/NVS_20150127_bookdata.txt
# Saved to data/PFE_20150127_bookdata.txt
# Saved to data/MRK_20150127_bookdata.txt
# Saved to data/UNH_20150127_bookdata.txt
# Saved to data/XOM_20150127_bookdata.txt
# Saved to data/GE_20150127_bookdata.txt
# Saved to data/CVX_20150127_bookdata.txt
# Saved to data/TOT_20150127_bookdata.txt
# Saved to data/PTR_20150127_bookdata.txt
# Saved to data/IVV_20150127_bookdata.txt
# 20150128
# DONDONDON: it's now 18:05:00.869314
# Saved to data/PG_20150128_bookdata.txt
# Saved to data/UN_20150128_bookdata.txt
# Saved to data/UL_20150128_bookdata.txt
# Saved to data/BHP_20150128_bookdata.txt
# Saved to data/DOW_20150128_bookdata.txt
# Saved to data/AAPL_20150128_bookdata.txt
# Saved to data/GOOG_20150128_bookdata.txt
# Saved to data/MSFT_20150128_bookdata.txt
# Saved to data/FB_20150128_bookdata.txt
# Saved to data/ORCL_20150128_bookdata.txt
# Saved to data/JPM_20150128_bookdata.txt
# Saved to data/WFC_20150128_bookdata.txt
# Saved to data/BAC_20150128_bookdata.txt
# Saved to data/HSBC_20150128_bookdata.txt
# Saved to data/C_20150128_bookdata.txt
# Saved to data/JNJ_20150128_bookdata.txt
# Saved to data/NVS_20150128_bookdata.txt
# Saved to data/PFE_20150128_bookdata.txt
# Saved to data/MRK_20150128_bookdata.txt
# Saved to data/UNH_20150128_bookdata.txt
# Saved to data/XOM_20150128_bookdata.txt
# Saved to data/GE_20150128_bookdata.txt
# Saved to data/CVX_20150128_bookdata.txt
# Saved to data/TOT_20150128_bookdata.txt
# Saved to data/PTR_20150128_bookdata.txt
# Saved to data/IVV_20150128_bookdata.txt
# 20150129
# DONDONDON: it's now 18:04:53.482379
# Saved to data/PG_20150129_bookdata.txt
# Saved to data/UN_20150129_bookdata.txt
# Saved to data/UL_20150129_bookdata.txt
# Saved to data/BHP_20150129_bookdata.txt
# Saved to data/DOW_20150129_bookdata.txt
# Saved to data/AAPL_20150129_bookdata.txt
# Saved to data/GOOG_20150129_bookdata.txt
# Saved to data/MSFT_20150129_bookdata.txt
# Saved to data/FB_20150129_bookdata.txt
# Saved to data/ORCL_20150129_bookdata.txt
# Saved to data/JPM_20150129_bookdata.txt
# Saved to data/WFC_20150129_bookdata.txt
# Saved to data/BAC_20150129_bookdata.txt
# Saved to data/HSBC_20150129_bookdata.txt
# Saved to data/C_20150129_bookdata.txt
# Saved to data/JNJ_20150129_bookdata.txt
# Saved to data/NVS_20150129_bookdata.txt
# Saved to data/PFE_20150129_bookdata.txt
# Saved to data/MRK_20150129_bookdata.txt
# Saved to data/UNH_20150129_bookdata.txt
# Saved to data/XOM_20150129_bookdata.txt
# Saved to data/GE_20150129_bookdata.txt
# Saved to data/CVX_20150129_bookdata.txt
# Saved to data/TOT_20150129_bookdata.txt
# Saved to data/PTR_20150129_bookdata.txt
# Saved to data/IVV_20150129_bookdata.txt
# 20150130
# DONDONDON: it's now 18:04:15.485851
# Saved to data/PG_20150130_bookdata.txt
# Saved to data/UN_20150130_bookdata.txt
# Saved to data/UL_20150130_bookdata.txt
# Saved to data/BHP_20150130_bookdata.txt
# Saved to data/DOW_20150130_bookdata.txt
# Saved to data/AAPL_20150130_bookdata.txt
# Saved to data/GOOG_20150130_bookdata.txt
# Saved to data/MSFT_20150130_bookdata.txt
# Saved to data/FB_20150130_bookdata.txt
# Saved to data/ORCL_20150130_bookdata.txt
# Saved to data/JPM_20150130_bookdata.txt
# Saved to data/WFC_20150130_bookdata.txt
# Saved to data/BAC_20150130_bookdata.txt
# Saved to data/HSBC_20150130_bookdata.txt
# Saved to data/C_20150130_bookdata.txt
# Saved to data/JNJ_20150130_bookdata.txt
# Saved to data/NVS_20150130_bookdata.txt
# Saved to data/PFE_20150130_bookdata.txt
# Saved to data/MRK_20150130_bookdata.txt
# Saved to data/UNH_20150130_bookdata.txt
# Saved to data/XOM_20150130_bookdata.txt
# Saved to data/GE_20150130_bookdata.txt
# Saved to data/CVX_20150130_bookdata.txt
# Saved to data/TOT_20150130_bookdata.txt
# Saved to data/PTR_20150130_bookdata.txt
# Saved to data/IVV_20150130_bookdata.txt
# 20150202
# DONDONDON: it's now 18:04:50.500232
# Saved to data/PG_20150202_bookdata.txt
# Saved to data/UN_20150202_bookdata.txt
# Saved to data/UL_20150202_bookdata.txt
# Saved to data/BHP_20150202_bookdata.txt
# Saved to data/DOW_20150202_bookdata.txt
# Saved to data/AAPL_20150202_bookdata.txt
# Saved to data/GOOG_20150202_bookdata.txt
# Saved to data/MSFT_20150202_bookdata.txt
# Saved to data/FB_20150202_bookdata.txt
# Saved to data/ORCL_20150202_bookdata.txt
# Saved to data/JPM_20150202_bookdata.txt
# Saved to data/WFC_20150202_bookdata.txt
# Saved to data/BAC_20150202_bookdata.txt
# Saved to data/HSBC_20150202_bookdata.txt
# Saved to data/C_20150202_bookdata.txt
# Saved to data/JNJ_20150202_bookdata.txt
# Saved to data/NVS_20150202_bookdata.txt
# Saved to data/PFE_20150202_bookdata.txt
# Saved to data/MRK_20150202_bookdata.txt
# Saved to data/UNH_20150202_bookdata.txt
# Saved to data/XOM_20150202_bookdata.txt
# Saved to data/GE_20150202_bookdata.txt
# Saved to data/CVX_20150202_bookdata.txt
# Saved to data/TOT_20150202_bookdata.txt
# Saved to data/PTR_20150202_bookdata.txt
# Saved to data/IVV_20150202_bookdata.txt
# 20150203
# DONDONDON: it's now 18:04:57.999621
# Saved to data/PG_20150203_bookdata.txt
# Saved to data/UN_20150203_bookdata.txt
# Saved to data/UL_20150203_bookdata.txt
# Saved to data/BHP_20150203_bookdata.txt
# Saved to data/DOW_20150203_bookdata.txt
# Saved to data/AAPL_20150203_bookdata.txt
# Saved to data/GOOG_20150203_bookdata.txt
# Saved to data/MSFT_20150203_bookdata.txt
# Saved to data/FB_20150203_bookdata.txt
# Saved to data/ORCL_20150203_bookdata.txt
# Saved to data/JPM_20150203_bookdata.txt
# Saved to data/WFC_20150203_bookdata.txt
# Saved to data/BAC_20150203_bookdata.txt
# Saved to data/HSBC_20150203_bookdata.txt
# Saved to data/C_20150203_bookdata.txt
# Saved to data/JNJ_20150203_bookdata.txt
# Saved to data/NVS_20150203_bookdata.txt
# Saved to data/PFE_20150203_bookdata.txt
# Saved to data/MRK_20150203_bookdata.txt
# Saved to data/UNH_20150203_bookdata.txt
# Saved to data/XOM_20150203_bookdata.txt
# Saved to data/GE_20150203_bookdata.txt
# Saved to data/CVX_20150203_bookdata.txt
# Saved to data/TOT_20150203_bookdata.txt
# Saved to data/PTR_20150203_bookdata.txt
# Saved to data/IVV_20150203_bookdata.txt
# 20150204
# DONDONDON: it's now 18:04:54.161195
# Saved to data/PG_20150204_bookdata.txt
# Saved to data/UN_20150204_bookdata.txt
# Saved to data/UL_20150204_bookdata.txt
# Saved to data/BHP_20150204_bookdata.txt
# Saved to data/DOW_20150204_bookdata.txt
# Saved to data/AAPL_20150204_bookdata.txt
# Saved to data/GOOG_20150204_bookdata.txt
# Saved to data/MSFT_20150204_bookdata.txt
# Saved to data/FB_20150204_bookdata.txt
# Saved to data/ORCL_20150204_bookdata.txt
# Saved to data/JPM_20150204_bookdata.txt
# Saved to data/WFC_20150204_bookdata.txt
# Saved to data/BAC_20150204_bookdata.txt
# Saved to data/HSBC_20150204_bookdata.txt
# Saved to data/C_20150204_bookdata.txt
# Saved to data/JNJ_20150204_bookdata.txt
# Saved to data/NVS_20150204_bookdata.txt
# Saved to data/PFE_20150204_bookdata.txt
# Saved to data/MRK_20150204_bookdata.txt
# Saved to data/UNH_20150204_bookdata.txt
# Saved to data/XOM_20150204_bookdata.txt
# Saved to data/GE_20150204_bookdata.txt
# Saved to data/CVX_20150204_bookdata.txt
# Saved to data/TOT_20150204_bookdata.txt
# Saved to data/PTR_20150204_bookdata.txt
# Saved to data/IVV_20150204_bookdata.txt
# 20150205
# DONDONDON: it's now 18:04:59.772353
# Saved to data/PG_20150205_bookdata.txt
# Saved to data/UN_20150205_bookdata.txt
# Saved to data/UL_20150205_bookdata.txt
# Saved to data/BHP_20150205_bookdata.txt
# Saved to data/DOW_20150205_bookdata.txt
# Saved to data/AAPL_20150205_bookdata.txt
# Saved to data/GOOG_20150205_bookdata.txt
# Saved to data/MSFT_20150205_bookdata.txt
# Saved to data/FB_20150205_bookdata.txt
# Saved to data/ORCL_20150205_bookdata.txt
# Saved to data/JPM_20150205_bookdata.txt
# Saved to data/WFC_20150205_bookdata.txt
# Saved to data/BAC_20150205_bookdata.txt
# Saved to data/HSBC_20150205_bookdata.txt
# Saved to data/C_20150205_bookdata.txt
# Saved to data/JNJ_20150205_bookdata.txt
# Saved to data/NVS_20150205_bookdata.txt
# Saved to data/PFE_20150205_bookdata.txt
# Saved to data/MRK_20150205_bookdata.txt
# Saved to data/UNH_20150205_bookdata.txt
# Saved to data/XOM_20150205_bookdata.txt
# Saved to data/GE_20150205_bookdata.txt
# Saved to data/CVX_20150205_bookdata.txt
# Saved to data/TOT_20150205_bookdata.txt
# Saved to data/PTR_20150205_bookdata.txt
# Saved to data/IVV_20150205_bookdata.txt
# 20150206
# DONDONDON: it's now 18:04:46.895004
# Saved to data/PG_20150206_bookdata.txt
# Saved to data/UN_20150206_bookdata.txt
# Saved to data/UL_20150206_bookdata.txt
# Saved to data/BHP_20150206_bookdata.txt
# Saved to data/DOW_20150206_bookdata.txt
# Saved to data/AAPL_20150206_bookdata.txt
# Saved to data/GOOG_20150206_bookdata.txt
# Saved to data/MSFT_20150206_bookdata.txt
# Saved to data/FB_20150206_bookdata.txt
# Saved to data/ORCL_20150206_bookdata.txt
# Saved to data/JPM_20150206_bookdata.txt
# Saved to data/WFC_20150206_bookdata.txt
# Saved to data/BAC_20150206_bookdata.txt
# Saved to data/HSBC_20150206_bookdata.txt
# Saved to data/C_20150206_bookdata.txt
# Saved to data/JNJ_20150206_bookdata.txt
# Saved to data/NVS_20150206_bookdata.txt
# Saved to data/PFE_20150206_bookdata.txt
# Saved to data/MRK_20150206_bookdata.txt
# Saved to data/UNH_20150206_bookdata.txt
# Saved to data/XOM_20150206_bookdata.txt
# Saved to data/GE_20150206_bookdata.txt
# Saved to data/CVX_20150206_bookdata.txt
# Saved to data/TOT_20150206_bookdata.txt
# Saved to data/PTR_20150206_bookdata.txt
# Saved to data/IVV_20150206_bookdata.txt
# 20150209
# DONDONDON: it's now 18:04:52.685294
# Saved to data/PG_20150209_bookdata.txt
# Saved to data/UN_20150209_bookdata.txt
# Saved to data/UL_20150209_bookdata.txt
# Saved to data/BHP_20150209_bookdata.txt
# Saved to data/DOW_20150209_bookdata.txt
# Saved to data/AAPL_20150209_bookdata.txt
# Saved to data/GOOG_20150209_bookdata.txt
# Saved to data/MSFT_20150209_bookdata.txt
# Saved to data/FB_20150209_bookdata.txt
# Saved to data/ORCL_20150209_bookdata.txt
# Saved to data/JPM_20150209_bookdata.txt
# Saved to data/WFC_20150209_bookdata.txt
# Saved to data/BAC_20150209_bookdata.txt
# Saved to data/HSBC_20150209_bookdata.txt
# Saved to data/C_20150209_bookdata.txt
# Saved to data/JNJ_20150209_bookdata.txt
# Saved to data/NVS_20150209_bookdata.txt
# Saved to data/PFE_20150209_bookdata.txt
# Saved to data/MRK_20150209_bookdata.txt
# Saved to data/UNH_20150209_bookdata.txt
# Saved to data/XOM_20150209_bookdata.txt
# Saved to data/GE_20150209_bookdata.txt
# Saved to data/CVX_20150209_bookdata.txt
# Saved to data/TOT_20150209_bookdata.txt
# Saved to data/PTR_20150209_bookdata.txt
# Saved to data/IVV_20150209_bookdata.txt
# 20150210
# DONDONDON: it's now 18:04:51.910107
# Saved to data/PG_20150210_bookdata.txt
# Saved to data/UN_20150210_bookdata.txt
# Saved to data/UL_20150210_bookdata.txt
# Saved to data/BHP_20150210_bookdata.txt
# Saved to data/DOW_20150210_bookdata.txt
# Saved to data/AAPL_20150210_bookdata.txt
# Saved to data/GOOG_20150210_bookdata.txt
# Saved to data/MSFT_20150210_bookdata.txt
# Saved to data/FB_20150210_bookdata.txt
# Saved to data/ORCL_20150210_bookdata.txt
# Saved to data/JPM_20150210_bookdata.txt
# Saved to data/WFC_20150210_bookdata.txt
# Saved to data/BAC_20150210_bookdata.txt
# Saved to data/HSBC_20150210_bookdata.txt
# Saved to data/C_20150210_bookdata.txt
# Saved to data/JNJ_20150210_bookdata.txt
# Saved to data/NVS_20150210_bookdata.txt
# Saved to data/PFE_20150210_bookdata.txt
# Saved to data/MRK_20150210_bookdata.txt
# Saved to data/UNH_20150210_bookdata.txt
# Saved to data/XOM_20150210_bookdata.txt
# Saved to data/GE_20150210_bookdata.txt
# Saved to data/CVX_20150210_bookdata.txt
# Saved to data/TOT_20150210_bookdata.txt
# Saved to data/PTR_20150210_bookdata.txt
# Saved to data/IVV_20150210_bookdata.txt
# 20150211
# DONDONDON: it's now 18:04:53.918003
# Saved to data/PG_20150211_bookdata.txt
# Saved to data/UN_20150211_bookdata.txt
# Saved to data/UL_20150211_bookdata.txt
# Saved to data/BHP_20150211_bookdata.txt
# Saved to data/DOW_20150211_bookdata.txt
# Saved to data/AAPL_20150211_bookdata.txt
# Saved to data/GOOG_20150211_bookdata.txt
# Saved to data/MSFT_20150211_bookdata.txt
# Saved to data/FB_20150211_bookdata.txt
# Saved to data/ORCL_20150211_bookdata.txt
# Saved to data/JPM_20150211_bookdata.txt
# Saved to data/WFC_20150211_bookdata.txt
# Saved to data/BAC_20150211_bookdata.txt
# Saved to data/HSBC_20150211_bookdata.txt
# Saved to data/C_20150211_bookdata.txt
# Saved to data/JNJ_20150211_bookdata.txt
# Saved to data/NVS_20150211_bookdata.txt
# Saved to data/PFE_20150211_bookdata.txt
# Saved to data/MRK_20150211_bookdata.txt
# Saved to data/UNH_20150211_bookdata.txt
# Saved to data/XOM_20150211_bookdata.txt
# Saved to data/GE_20150211_bookdata.txt
# Saved to data/CVX_20150211_bookdata.txt
# Saved to data/TOT_20150211_bookdata.txt
# Saved to data/PTR_20150211_bookdata.txt
# Saved to data/IVV_20150211_bookdata.txt
# 20150212
# DONDONDON: it's now 18:04:42.347533
# Saved to data/PG_20150212_bookdata.txt
# Saved to data/UN_20150212_bookdata.txt
# Saved to data/UL_20150212_bookdata.txt
# Saved to data/BHP_20150212_bookdata.txt
# Saved to data/DOW_20150212_bookdata.txt
# Saved to data/AAPL_20150212_bookdata.txt
# Saved to data/GOOG_20150212_bookdata.txt
# Saved to data/MSFT_20150212_bookdata.txt
# Saved to data/FB_20150212_bookdata.txt
# Saved to data/ORCL_20150212_bookdata.txt
# Saved to data/JPM_20150212_bookdata.txt
# Saved to data/WFC_20150212_bookdata.txt
# Saved to data/BAC_20150212_bookdata.txt
# Saved to data/HSBC_20150212_bookdata.txt
# Saved to data/C_20150212_bookdata.txt
# Saved to data/JNJ_20150212_bookdata.txt
# Saved to data/NVS_20150212_bookdata.txt
# Saved to data/PFE_20150212_bookdata.txt
# Saved to data/MRK_20150212_bookdata.txt
# Saved to data/UNH_20150212_bookdata.txt
# Saved to data/XOM_20150212_bookdata.txt
# Saved to data/GE_20150212_bookdata.txt
# Saved to data/CVX_20150212_bookdata.txt
# Saved to data/TOT_20150212_bookdata.txt
# Saved to data/PTR_20150212_bookdata.txt
# Saved to data/IVV_20150212_bookdata.txt
# 20150213
# DONDONDON: it's now 18:04:50.431476
# Saved to data/PG_20150213_bookdata.txt
# Saved to data/UN_20150213_bookdata.txt
# Saved to data/UL_20150213_bookdata.txt
# Saved to data/BHP_20150213_bookdata.txt
# Saved to data/DOW_20150213_bookdata.txt
# Saved to data/AAPL_20150213_bookdata.txt
# Saved to data/GOOG_20150213_bookdata.txt
# Saved to data/MSFT_20150213_bookdata.txt
# Saved to data/FB_20150213_bookdata.txt
# Saved to data/ORCL_20150213_bookdata.txt
# Saved to data/JPM_20150213_bookdata.txt
# Saved to data/WFC_20150213_bookdata.txt
# Saved to data/BAC_20150213_bookdata.txt
# Saved to data/HSBC_20150213_bookdata.txt
# Saved to data/C_20150213_bookdata.txt
# Saved to data/JNJ_20150213_bookdata.txt
# Saved to data/NVS_20150213_bookdata.txt
# Saved to data/PFE_20150213_bookdata.txt
# Saved to data/MRK_20150213_bookdata.txt
# Saved to data/UNH_20150213_bookdata.txt
# Saved to data/XOM_20150213_bookdata.txt
# Saved to data/GE_20150213_bookdata.txt
# Saved to data/CVX_20150213_bookdata.txt
# Saved to data/TOT_20150213_bookdata.txt
# Saved to data/PTR_20150213_bookdata.txt
# Saved to data/IVV_20150213_bookdata.txt
# 20150216
# 20150217
# DONDONDON: it's now 18:04:57.949817
# Saved to data/PG_20150217_bookdata.txt
# Saved to data/UN_20150217_bookdata.txt
# Saved to data/UL_20150217_bookdata.txt
# Saved to data/BHP_20150217_bookdata.txt
# Saved to data/DOW_20150217_bookdata.txt
# Saved to data/AAPL_20150217_bookdata.txt
# Saved to data/GOOG_20150217_bookdata.txt
# Saved to data/MSFT_20150217_bookdata.txt
# Saved to data/FB_20150217_bookdata.txt
# Saved to data/ORCL_20150217_bookdata.txt
# Saved to data/JPM_20150217_bookdata.txt
# Saved to data/WFC_20150217_bookdata.txt
# Saved to data/BAC_20150217_bookdata.txt
# Saved to data/HSBC_20150217_bookdata.txt
# Saved to data/C_20150217_bookdata.txt
# Saved to data/JNJ_20150217_bookdata.txt
# Saved to data/NVS_20150217_bookdata.txt
# Saved to data/PFE_20150217_bookdata.txt
# Saved to data/MRK_20150217_bookdata.txt
# Saved to data/UNH_20150217_bookdata.txt
# Saved to data/XOM_20150217_bookdata.txt
# Saved to data/GE_20150217_bookdata.txt
# Saved to data/CVX_20150217_bookdata.txt
# Saved to data/TOT_20150217_bookdata.txt
# Saved to data/PTR_20150217_bookdata.txt
# Saved to data/IVV_20150217_bookdata.txt
# 20150218
# DONDONDON: it's now 18:04:58.583262
# Saved to data/PG_20150218_bookdata.txt
# Saved to data/UN_20150218_bookdata.txt
# Saved to data/UL_20150218_bookdata.txt
# Saved to data/BHP_20150218_bookdata.txt
# Saved to data/DOW_20150218_bookdata.txt
# Saved to data/AAPL_20150218_bookdata.txt
# Saved to data/GOOG_20150218_bookdata.txt
# Saved to data/MSFT_20150218_bookdata.txt
# Saved to data/FB_20150218_bookdata.txt
# Saved to data/ORCL_20150218_bookdata.txt
# Saved to data/JPM_20150218_bookdata.txt
# Saved to data/WFC_20150218_bookdata.txt
# Saved to data/BAC_20150218_bookdata.txt
# Saved to data/HSBC_20150218_bookdata.txt
# Saved to data/C_20150218_bookdata.txt
# Saved to data/JNJ_20150218_bookdata.txt
# Saved to data/NVS_20150218_bookdata.txt
# Saved to data/PFE_20150218_bookdata.txt
# Saved to data/MRK_20150218_bookdata.txt
# Saved to data/UNH_20150218_bookdata.txt
# Saved to data/XOM_20150218_bookdata.txt
# Saved to data/GE_20150218_bookdata.txt
# Saved to data/CVX_20150218_bookdata.txt
# Saved to data/TOT_20150218_bookdata.txt
# Saved to data/PTR_20150218_bookdata.txt
# Saved to data/IVV_20150218_bookdata.txt
# 20150219
# DONDONDON: it's now 18:04:54.001263
# Saved to data/PG_20150219_bookdata.txt
# Saved to data/UN_20150219_bookdata.txt
# Saved to data/UL_20150219_bookdata.txt
# Saved to data/BHP_20150219_bookdata.txt
# Saved to data/DOW_20150219_bookdata.txt
# Saved to data/AAPL_20150219_bookdata.txt
# Saved to data/GOOG_20150219_bookdata.txt
# Saved to data/MSFT_20150219_bookdata.txt
# Saved to data/FB_20150219_bookdata.txt
# Saved to data/ORCL_20150219_bookdata.txt
# Saved to data/JPM_20150219_bookdata.txt
# Saved to data/WFC_20150219_bookdata.txt
# Saved to data/BAC_20150219_bookdata.txt
# Saved to data/HSBC_20150219_bookdata.txt
# Saved to data/C_20150219_bookdata.txt
# Saved to data/JNJ_20150219_bookdata.txt
# Saved to data/NVS_20150219_bookdata.txt
# Saved to data/PFE_20150219_bookdata.txt
# Saved to data/MRK_20150219_bookdata.txt
# Saved to data/UNH_20150219_bookdata.txt
# Saved to data/XOM_20150219_bookdata.txt
# Saved to data/GE_20150219_bookdata.txt
# Saved to data/CVX_20150219_bookdata.txt
# Saved to data/TOT_20150219_bookdata.txt
# Saved to data/PTR_20150219_bookdata.txt
# Saved to data/IVV_20150219_bookdata.txt
# 20150220
# DONDONDON: it's now 18:04:59.368667
# Saved to data/PG_20150220_bookdata.txt
# Saved to data/UN_20150220_bookdata.txt
# Saved to data/UL_20150220_bookdata.txt
# Saved to data/BHP_20150220_bookdata.txt
# Saved to data/DOW_20150220_bookdata.txt
# Saved to data/AAPL_20150220_bookdata.txt
# Saved to data/GOOG_20150220_bookdata.txt
# Saved to data/MSFT_20150220_bookdata.txt
# Saved to data/FB_20150220_bookdata.txt
# Saved to data/ORCL_20150220_bookdata.txt
# Saved to data/JPM_20150220_bookdata.txt
# Saved to data/WFC_20150220_bookdata.txt
# Saved to data/BAC_20150220_bookdata.txt
# Saved to data/HSBC_20150220_bookdata.txt
# Saved to data/C_20150220_bookdata.txt
# Saved to data/JNJ_20150220_bookdata.txt
# Saved to data/NVS_20150220_bookdata.txt
# Saved to data/PFE_20150220_bookdata.txt
# Saved to data/MRK_20150220_bookdata.txt
# Saved to data/UNH_20150220_bookdata.txt
# Saved to data/XOM_20150220_bookdata.txt
# Saved to data/GE_20150220_bookdata.txt
# Saved to data/CVX_20150220_bookdata.txt
# Saved to data/TOT_20150220_bookdata.txt
# Saved to data/PTR_20150220_bookdata.txt
# Saved to data/IVV_20150220_bookdata.txt
# 20150223
# DONDONDON: it's now 18:04:59.147048
# Saved to data/PG_20150223_bookdata.txt
# Saved to data/UN_20150223_bookdata.txt
# Saved to data/UL_20150223_bookdata.txt
# Saved to data/BHP_20150223_bookdata.txt
# Saved to data/DOW_20150223_bookdata.txt
# Saved to data/AAPL_20150223_bookdata.txt
# Saved to data/GOOG_20150223_bookdata.txt
# Saved to data/MSFT_20150223_bookdata.txt
# Saved to data/FB_20150223_bookdata.txt
# Saved to data/ORCL_20150223_bookdata.txt
# Saved to data/JPM_20150223_bookdata.txt
# Saved to data/WFC_20150223_bookdata.txt
# Saved to data/BAC_20150223_bookdata.txt
# Saved to data/HSBC_20150223_bookdata.txt
# Saved to data/C_20150223_bookdata.txt
# Saved to data/JNJ_20150223_bookdata.txt
# Saved to data/NVS_20150223_bookdata.txt
# Saved to data/PFE_20150223_bookdata.txt
# Saved to data/MRK_20150223_bookdata.txt
# Saved to data/UNH_20150223_bookdata.txt
# Saved to data/XOM_20150223_bookdata.txt
# Saved to data/GE_20150223_bookdata.txt
# Saved to data/CVX_20150223_bookdata.txt
# Saved to data/TOT_20150223_bookdata.txt
# Saved to data/PTR_20150223_bookdata.txt
# Saved to data/IVV_20150223_bookdata.txt
# 20150224
# DONDONDON: it's now 18:04:48.588968
# Saved to data/PG_20150224_bookdata.txt
# Saved to data/UN_20150224_bookdata.txt
# Saved to data/UL_20150224_bookdata.txt
# Saved to data/BHP_20150224_bookdata.txt
# Saved to data/DOW_20150224_bookdata.txt
# Saved to data/AAPL_20150224_bookdata.txt
# Saved to data/GOOG_20150224_bookdata.txt
# Saved to data/MSFT_20150224_bookdata.txt
# Saved to data/FB_20150224_bookdata.txt
# Saved to data/ORCL_20150224_bookdata.txt
# Saved to data/JPM_20150224_bookdata.txt
# Saved to data/WFC_20150224_bookdata.txt
# Saved to data/BAC_20150224_bookdata.txt
# Saved to data/HSBC_20150224_bookdata.txt
# Saved to data/C_20150224_bookdata.txt
# Saved to data/JNJ_20150224_bookdata.txt
# Saved to data/NVS_20150224_bookdata.txt
# Saved to data/PFE_20150224_bookdata.txt
# Saved to data/MRK_20150224_bookdata.txt
# Saved to data/UNH_20150224_bookdata.txt
# Saved to data/XOM_20150224_bookdata.txt
# Saved to data/GE_20150224_bookdata.txt
# Saved to data/CVX_20150224_bookdata.txt
# Saved to data/TOT_20150224_bookdata.txt
# Saved to data/PTR_20150224_bookdata.txt
# Saved to data/IVV_20150224_bookdata.txt
# 20150225
# DONDONDON: it's now 18:04:46.130277
# Saved to data/PG_20150225_bookdata.txt
# Saved to data/UN_20150225_bookdata.txt
# Saved to data/UL_20150225_bookdata.txt
# Saved to data/BHP_20150225_bookdata.txt
# Saved to data/DOW_20150225_bookdata.txt
# Saved to data/AAPL_20150225_bookdata.txt
# Saved to data/GOOG_20150225_bookdata.txt
# Saved to data/MSFT_20150225_bookdata.txt
# Saved to data/FB_20150225_bookdata.txt
# Saved to data/ORCL_20150225_bookdata.txt
# Saved to data/JPM_20150225_bookdata.txt
# Saved to data/WFC_20150225_bookdata.txt
# Saved to data/BAC_20150225_bookdata.txt
# Saved to data/HSBC_20150225_bookdata.txt
# Saved to data/C_20150225_bookdata.txt
# Saved to data/JNJ_20150225_bookdata.txt
# Saved to data/NVS_20150225_bookdata.txt
# Saved to data/PFE_20150225_bookdata.txt
# Saved to data/MRK_20150225_bookdata.txt
# Saved to data/UNH_20150225_bookdata.txt
# Saved to data/XOM_20150225_bookdata.txt
# Saved to data/GE_20150225_bookdata.txt
# Saved to data/CVX_20150225_bookdata.txt
# Saved to data/TOT_20150225_bookdata.txt
# Saved to data/PTR_20150225_bookdata.txt
# Saved to data/IVV_20150225_bookdata.txt
# 20150226
# DONDONDON: it's now 18:04:46.493082
# Saved to data/PG_20150226_bookdata.txt
# Saved to data/UN_20150226_bookdata.txt
# Saved to data/UL_20150226_bookdata.txt
# Saved to data/BHP_20150226_bookdata.txt
# Saved to data/DOW_20150226_bookdata.txt
# Saved to data/AAPL_20150226_bookdata.txt
# Saved to data/GOOG_20150226_bookdata.txt
# Saved to data/MSFT_20150226_bookdata.txt
# Saved to data/FB_20150226_bookdata.txt
# Saved to data/ORCL_20150226_bookdata.txt
# Saved to data/JPM_20150226_bookdata.txt
# Saved to data/WFC_20150226_bookdata.txt
# Saved to data/BAC_20150226_bookdata.txt
# Saved to data/HSBC_20150226_bookdata.txt
# Saved to data/C_20150226_bookdata.txt
# Saved to data/JNJ_20150226_bookdata.txt
# Saved to data/NVS_20150226_bookdata.txt
# Saved to data/PFE_20150226_bookdata.txt
# Saved to data/MRK_20150226_bookdata.txt
# Saved to data/UNH_20150226_bookdata.txt
# Saved to data/XOM_20150226_bookdata.txt
# Saved to data/GE_20150226_bookdata.txt
# Saved to data/CVX_20150226_bookdata.txt
# Saved to data/TOT_20150226_bookdata.txt
# Saved to data/PTR_20150226_bookdata.txt
# Saved to data/IVV_20150226_bookdata.txt
# 20150227
# DONDONDON: it's now 18:04:59.730241
# Saved to data/PG_20150227_bookdata.txt
# Saved to data/UN_20150227_bookdata.txt
# Saved to data/UL_20150227_bookdata.txt
# Saved to data/BHP_20150227_bookdata.txt
# Saved to data/DOW_20150227_bookdata.txt
# Saved to data/AAPL_20150227_bookdata.txt
# Saved to data/GOOG_20150227_bookdata.txt
# Saved to data/MSFT_20150227_bookdata.txt
# Saved to data/FB_20150227_bookdata.txt
# Saved to data/ORCL_20150227_bookdata.txt
# Saved to data/JPM_20150227_bookdata.txt
# Saved to data/WFC_20150227_bookdata.txt
# Saved to data/BAC_20150227_bookdata.txt
# Saved to data/HSBC_20150227_bookdata.txt
# Saved to data/C_20150227_bookdata.txt
# Saved to data/JNJ_20150227_bookdata.txt
# Saved to data/NVS_20150227_bookdata.txt
# Saved to data/PFE_20150227_bookdata.txt
# Saved to data/MRK_20150227_bookdata.txt
# Saved to data/UNH_20150227_bookdata.txt
# Saved to data/XOM_20150227_bookdata.txt
# Saved to data/GE_20150227_bookdata.txt
# Saved to data/CVX_20150227_bookdata.txt
# Saved to data/TOT_20150227_bookdata.txt
# Saved to data/PTR_20150227_bookdata.txt
# Saved to data/IVV_20150227_bookdata.txt
# 20150302
# DONDONDON: it's now 18:04:51.543322
# Saved to data/PG_20150302_bookdata.txt
# Saved to data/UN_20150302_bookdata.txt
# Saved to data/UL_20150302_bookdata.txt
# Saved to data/BHP_20150302_bookdata.txt
# Saved to data/DOW_20150302_bookdata.txt
# Saved to data/AAPL_20150302_bookdata.txt
# Saved to data/GOOG_20150302_bookdata.txt
# Saved to data/MSFT_20150302_bookdata.txt
# Saved to data/FB_20150302_bookdata.txt
# Saved to data/ORCL_20150302_bookdata.txt
# Saved to data/JPM_20150302_bookdata.txt
# Saved to data/WFC_20150302_bookdata.txt
# Saved to data/BAC_20150302_bookdata.txt
# Saved to data/HSBC_20150302_bookdata.txt
# Saved to data/C_20150302_bookdata.txt
# Saved to data/JNJ_20150302_bookdata.txt
# Saved to data/NVS_20150302_bookdata.txt
# Saved to data/PFE_20150302_bookdata.txt
# Saved to data/MRK_20150302_bookdata.txt
# Saved to data/UNH_20150302_bookdata.txt
# Saved to data/XOM_20150302_bookdata.txt
# Saved to data/GE_20150302_bookdata.txt
# Saved to data/CVX_20150302_bookdata.txt
# Saved to data/TOT_20150302_bookdata.txt
# Saved to data/PTR_20150302_bookdata.txt
# Saved to data/IVV_20150302_bookdata.txt
# 20150303
# DONDONDON: it's now 18:04:55.006801
# Saved to data/PG_20150303_bookdata.txt
# Saved to data/UN_20150303_bookdata.txt
# Saved to data/UL_20150303_bookdata.txt
# Saved to data/BHP_20150303_bookdata.txt
# Saved to data/DOW_20150303_bookdata.txt
# Saved to data/AAPL_20150303_bookdata.txt
# Saved to data/GOOG_20150303_bookdata.txt
# Saved to data/MSFT_20150303_bookdata.txt
# Saved to data/FB_20150303_bookdata.txt
# Saved to data/ORCL_20150303_bookdata.txt
# Saved to data/JPM_20150303_bookdata.txt
# Saved to data/WFC_20150303_bookdata.txt
# Saved to data/BAC_20150303_bookdata.txt
# Saved to data/HSBC_20150303_bookdata.txt
# Saved to data/C_20150303_bookdata.txt
# Saved to data/JNJ_20150303_bookdata.txt
# Saved to data/NVS_20150303_bookdata.txt
# Saved to data/PFE_20150303_bookdata.txt
# Saved to data/MRK_20150303_bookdata.txt
# Saved to data/UNH_20150303_bookdata.txt
# Saved to data/XOM_20150303_bookdata.txt
# Saved to data/GE_20150303_bookdata.txt
# Saved to data/CVX_20150303_bookdata.txt
# Saved to data/TOT_20150303_bookdata.txt
# Saved to data/PTR_20150303_bookdata.txt
# Saved to data/IVV_20150303_bookdata.txt
# 20150304
# DONDONDON: it's now 18:04:57.921835
# Saved to data/PG_20150304_bookdata.txt
# Saved to data/UN_20150304_bookdata.txt
# Saved to data/UL_20150304_bookdata.txt
# Saved to data/BHP_20150304_bookdata.txt
# Saved to data/DOW_20150304_bookdata.txt
# Saved to data/AAPL_20150304_bookdata.txt
# Saved to data/GOOG_20150304_bookdata.txt
# Saved to data/MSFT_20150304_bookdata.txt
# Saved to data/FB_20150304_bookdata.txt
# Saved to data/ORCL_20150304_bookdata.txt
# Saved to data/JPM_20150304_bookdata.txt
# Saved to data/WFC_20150304_bookdata.txt
# Saved to data/BAC_20150304_bookdata.txt
# Saved to data/HSBC_20150304_bookdata.txt
# Saved to data/C_20150304_bookdata.txt
# Saved to data/JNJ_20150304_bookdata.txt
# Saved to data/NVS_20150304_bookdata.txt
# Saved to data/PFE_20150304_bookdata.txt
# Saved to data/MRK_20150304_bookdata.txt
# Saved to data/UNH_20150304_bookdata.txt
# Saved to data/XOM_20150304_bookdata.txt
# Saved to data/GE_20150304_bookdata.txt
# Saved to data/CVX_20150304_bookdata.txt
# Saved to data/TOT_20150304_bookdata.txt
# Saved to data/PTR_20150304_bookdata.txt
# Saved to data/IVV_20150304_bookdata.txt
# 20150305
# DONDONDON: it's now 18:04:56.374378
# Saved to data/PG_20150305_bookdata.txt
# Saved to data/UN_20150305_bookdata.txt
# Saved to data/UL_20150305_bookdata.txt
# Saved to data/BHP_20150305_bookdata.txt
# Saved to data/DOW_20150305_bookdata.txt
# Saved to data/AAPL_20150305_bookdata.txt
# Saved to data/GOOG_20150305_bookdata.txt
# Saved to data/MSFT_20150305_bookdata.txt
# Saved to data/FB_20150305_bookdata.txt
# Saved to data/ORCL_20150305_bookdata.txt
# Saved to data/JPM_20150305_bookdata.txt
# Saved to data/WFC_20150305_bookdata.txt
# Saved to data/BAC_20150305_bookdata.txt
# Saved to data/HSBC_20150305_bookdata.txt
# Saved to data/C_20150305_bookdata.txt
# Saved to data/JNJ_20150305_bookdata.txt
# Saved to data/NVS_20150305_bookdata.txt
# Saved to data/PFE_20150305_bookdata.txt
# Saved to data/MRK_20150305_bookdata.txt
# Saved to data/UNH_20150305_bookdata.txt
# Saved to data/XOM_20150305_bookdata.txt
# Saved to data/GE_20150305_bookdata.txt
# Saved to data/CVX_20150305_bookdata.txt
# Saved to data/TOT_20150305_bookdata.txt
# Saved to data/PTR_20150305_bookdata.txt
# Saved to data/IVV_20150305_bookdata.txt
# 20150306
# DONDONDON: it's now 18:04:58.532735
# Saved to data/PG_20150306_bookdata.txt
# Saved to data/UN_20150306_bookdata.txt
# Saved to data/UL_20150306_bookdata.txt
# Saved to data/BHP_20150306_bookdata.txt
# Saved to data/DOW_20150306_bookdata.txt
# Saved to data/AAPL_20150306_bookdata.txt
# Saved to data/GOOG_20150306_bookdata.txt
# Saved to data/MSFT_20150306_bookdata.txt
# Saved to data/FB_20150306_bookdata.txt
# Saved to data/ORCL_20150306_bookdata.txt
# Saved to data/JPM_20150306_bookdata.txt
# Saved to data/WFC_20150306_bookdata.txt
# Saved to data/BAC_20150306_bookdata.txt
# Saved to data/HSBC_20150306_bookdata.txt
# Saved to data/C_20150306_bookdata.txt
# Saved to data/JNJ_20150306_bookdata.txt
# Saved to data/NVS_20150306_bookdata.txt
# Saved to data/PFE_20150306_bookdata.txt
# Saved to data/MRK_20150306_bookdata.txt
# Saved to data/UNH_20150306_bookdata.txt
# Saved to data/XOM_20150306_bookdata.txt
# Saved to data/GE_20150306_bookdata.txt
# Saved to data/CVX_20150306_bookdata.txt
# Saved to data/TOT_20150306_bookdata.txt
# Saved to data/PTR_20150306_bookdata.txt
# Saved to data/IVV_20150306_bookdata.txt
# 20150309
# DONDONDON: it's now 18:04:51.414059
# Saved to data/PG_20150309_bookdata.txt
# Saved to data/UN_20150309_bookdata.txt
# Saved to data/UL_20150309_bookdata.txt
# Saved to data/BHP_20150309_bookdata.txt
# Saved to data/DOW_20150309_bookdata.txt
# Saved to data/AAPL_20150309_bookdata.txt
# Saved to data/GOOG_20150309_bookdata.txt
# Saved to data/MSFT_20150309_bookdata.txt
# Saved to data/FB_20150309_bookdata.txt
# Saved to data/ORCL_20150309_bookdata.txt
# Saved to data/JPM_20150309_bookdata.txt
# Saved to data/WFC_20150309_bookdata.txt
# Saved to data/BAC_20150309_bookdata.txt
# Saved to data/HSBC_20150309_bookdata.txt
# Saved to data/C_20150309_bookdata.txt
# Saved to data/JNJ_20150309_bookdata.txt
# Saved to data/NVS_20150309_bookdata.txt
# Saved to data/PFE_20150309_bookdata.txt
# Saved to data/MRK_20150309_bookdata.txt
# Saved to data/UNH_20150309_bookdata.txt
# Saved to data/XOM_20150309_bookdata.txt
# Saved to data/GE_20150309_bookdata.txt
# Saved to data/CVX_20150309_bookdata.txt
# Saved to data/TOT_20150309_bookdata.txt
# Saved to data/PTR_20150309_bookdata.txt
# Saved to data/IVV_20150309_bookdata.txt
# 20150310
# DONDONDON: it's now 18:04:55.504889
# Saved to data/PG_20150310_bookdata.txt
# Saved to data/UN_20150310_bookdata.txt
# Saved to data/UL_20150310_bookdata.txt
# Saved to data/BHP_20150310_bookdata.txt
# Saved to data/DOW_20150310_bookdata.txt
# Saved to data/AAPL_20150310_bookdata.txt
# Saved to data/GOOG_20150310_bookdata.txt
# Saved to data/MSFT_20150310_bookdata.txt
# Saved to data/FB_20150310_bookdata.txt
# Saved to data/ORCL_20150310_bookdata.txt
# Saved to data/JPM_20150310_bookdata.txt
# Saved to data/WFC_20150310_bookdata.txt
# Saved to data/BAC_20150310_bookdata.txt
# Saved to data/HSBC_20150310_bookdata.txt
# Saved to data/C_20150310_bookdata.txt
# Saved to data/JNJ_20150310_bookdata.txt
# Saved to data/NVS_20150310_bookdata.txt
# Saved to data/PFE_20150310_bookdata.txt
# Saved to data/MRK_20150310_bookdata.txt
# Saved to data/UNH_20150310_bookdata.txt
# Saved to data/XOM_20150310_bookdata.txt
# Saved to data/GE_20150310_bookdata.txt
# Saved to data/CVX_20150310_bookdata.txt
# Saved to data/TOT_20150310_bookdata.txt
# Saved to data/PTR_20150310_bookdata.txt
# Saved to data/IVV_20150310_bookdata.txt
# 20150311
# DONDONDON: it's now 18:04:58.540268
# Saved to data/PG_20150311_bookdata.txt
# Saved to data/UN_20150311_bookdata.txt
# Saved to data/UL_20150311_bookdata.txt
# Saved to data/BHP_20150311_bookdata.txt
# Saved to data/DOW_20150311_bookdata.txt
# Saved to data/AAPL_20150311_bookdata.txt
# Saved to data/GOOG_20150311_bookdata.txt
# Saved to data/MSFT_20150311_bookdata.txt
# Saved to data/FB_20150311_bookdata.txt
# Saved to data/ORCL_20150311_bookdata.txt
# Saved to data/JPM_20150311_bookdata.txt
# Saved to data/WFC_20150311_bookdata.txt
# Saved to data/BAC_20150311_bookdata.txt
# Saved to data/HSBC_20150311_bookdata.txt
# Saved to data/C_20150311_bookdata.txt
# Saved to data/JNJ_20150311_bookdata.txt
# Saved to data/NVS_20150311_bookdata.txt
# Saved to data/PFE_20150311_bookdata.txt
# Saved to data/MRK_20150311_bookdata.txt
# Saved to data/UNH_20150311_bookdata.txt
# Saved to data/XOM_20150311_bookdata.txt
# Saved to data/GE_20150311_bookdata.txt
# Saved to data/CVX_20150311_bookdata.txt
# Saved to data/TOT_20150311_bookdata.txt
# Saved to data/PTR_20150311_bookdata.txt
# Saved to data/IVV_20150311_bookdata.txt
# 20150312
# DONDONDON: it's now 18:04:57.442556
# Saved to data/PG_20150312_bookdata.txt
# Saved to data/UN_20150312_bookdata.txt
# Saved to data/UL_20150312_bookdata.txt
# Saved to data/BHP_20150312_bookdata.txt
# Saved to data/DOW_20150312_bookdata.txt
# Saved to data/AAPL_20150312_bookdata.txt
# Saved to data/GOOG_20150312_bookdata.txt
# Saved to data/MSFT_20150312_bookdata.txt
# Saved to data/FB_20150312_bookdata.txt
# Saved to data/ORCL_20150312_bookdata.txt
# Saved to data/JPM_20150312_bookdata.txt
# Saved to data/WFC_20150312_bookdata.txt
# Saved to data/BAC_20150312_bookdata.txt
# Saved to data/HSBC_20150312_bookdata.txt
# Saved to data/C_20150312_bookdata.txt
# Saved to data/JNJ_20150312_bookdata.txt
# Saved to data/NVS_20150312_bookdata.txt
# Saved to data/PFE_20150312_bookdata.txt
# Saved to data/MRK_20150312_bookdata.txt
# Saved to data/UNH_20150312_bookdata.txt
# Saved to data/XOM_20150312_bookdata.txt
# Saved to data/GE_20150312_bookdata.txt
# Saved to data/CVX_20150312_bookdata.txt
# Saved to data/TOT_20150312_bookdata.txt
# Saved to data/PTR_20150312_bookdata.txt
# Saved to data/IVV_20150312_bookdata.txt
# 20150313
# DONDONDON: it's now 18:05:00.381352
# Saved to data/PG_20150313_bookdata.txt
# Saved to data/UN_20150313_bookdata.txt
# Saved to data/UL_20150313_bookdata.txt
# Saved to data/BHP_20150313_bookdata.txt
# Saved to data/DOW_20150313_bookdata.txt
# Saved to data/AAPL_20150313_bookdata.txt
# Saved to data/GOOG_20150313_bookdata.txt
# Saved to data/MSFT_20150313_bookdata.txt
# Saved to data/FB_20150313_bookdata.txt
# Saved to data/ORCL_20150313_bookdata.txt
# Saved to data/JPM_20150313_bookdata.txt
# Saved to data/WFC_20150313_bookdata.txt
# Saved to data/BAC_20150313_bookdata.txt
# Saved to data/HSBC_20150313_bookdata.txt
# Saved to data/C_20150313_bookdata.txt
# Saved to data/JNJ_20150313_bookdata.txt
# Saved to data/NVS_20150313_bookdata.txt
# Saved to data/PFE_20150313_bookdata.txt
# Saved to data/MRK_20150313_bookdata.txt
# Saved to data/UNH_20150313_bookdata.txt
# Saved to data/XOM_20150313_bookdata.txt
# Saved to data/GE_20150313_bookdata.txt
# Saved to data/CVX_20150313_bookdata.txt
# Saved to data/TOT_20150313_bookdata.txt
# Saved to data/PTR_20150313_bookdata.txt
# Saved to data/IVV_20150313_bookdata.txt
# 20150316
# DONDONDON: it's now 18:04:54.922675
# Saved to data/PG_20150316_bookdata.txt
# Saved to data/UN_20150316_bookdata.txt
# Saved to data/UL_20150316_bookdata.txt
# Saved to data/BHP_20150316_bookdata.txt
# Saved to data/DOW_20150316_bookdata.txt
# Saved to data/AAPL_20150316_bookdata.txt
# Saved to data/GOOG_20150316_bookdata.txt
# Saved to data/MSFT_20150316_bookdata.txt
# Saved to data/FB_20150316_bookdata.txt
# Saved to data/ORCL_20150316_bookdata.txt
# Saved to data/JPM_20150316_bookdata.txt
# Saved to data/WFC_20150316_bookdata.txt
# Saved to data/BAC_20150316_bookdata.txt
# Saved to data/HSBC_20150316_bookdata.txt
# Saved to data/C_20150316_bookdata.txt
# Saved to data/JNJ_20150316_bookdata.txt
# Saved to data/NVS_20150316_bookdata.txt
# Saved to data/PFE_20150316_bookdata.txt
# Saved to data/MRK_20150316_bookdata.txt
# Saved to data/UNH_20150316_bookdata.txt
# Saved to data/XOM_20150316_bookdata.txt
# Saved to data/GE_20150316_bookdata.txt
# Saved to data/CVX_20150316_bookdata.txt
# Saved to data/TOT_20150316_bookdata.txt
# Saved to data/PTR_20150316_bookdata.txt
# Saved to data/IVV_20150316_bookdata.txt
# 20150317
# DONDONDON: it's now 18:04:57.698476
# Saved to data/PG_20150317_bookdata.txt
# Saved to data/UN_20150317_bookdata.txt
# ...
# Saved to data/GOOG_20150320_bookdata.txt
# Saved to data/MSFT_20150320_bookdata.txt
# Saved to data/FB_20150320_bookdata.txt
# Saved to data/ORCL_20150320_bookdata.txt
# Saved to data/JPM_20150320_bookdata.txt
# Saved to data/WFC_20150320_bookdata.txt
# Saved to data/BAC_20150320_bookdata.txt
# Saved to data/HSBC_20150320_bookdata.txt
# Saved to data/C_20150320_bookdata.txt
# Saved to data/JNJ_20150320_bookdata.txt
# Saved to data/NVS_20150320_bookdata.txt
# Saved to data/PFE_20150320_bookdata.txt
# Saved to data/MRK_20150320_bookdata.txt
# Saved to data/UNH_20150320_bookdata.txt
# Saved to data/XOM_20150320_bookdata.txt
# Saved to data/GE_20150320_bookdata.txt
# Saved to data/CVX_20150320_bookdata.txt
# Saved to data/TOT_20150320_bookdata.txt
# Saved to data/PTR_20150320_bookdata.txt
# Saved to data/IVV_20150320_bookdata.txt
# 20150323
# DONDONDON: it's now 18:05:00.268746
# Saved to data/PG_20150323_bookdata.txt
# Saved to data/UN_20150323_bookdata.txt
# Saved to data/UL_20150323_bookdata.txt
# Saved to data/BHP_20150323_bookdata.txt
# Saved to data/DOW_20150323_bookdata.txt
# Saved to data/AAPL_20150323_bookdata.txt
# Saved to data/GOOG_20150323_bookdata.txt
# Saved to data/MSFT_20150323_bookdata.txt
# Saved to data/FB_20150323_bookdata.txt
# Saved to data/ORCL_20150323_bookdata.txt
# Saved to data/JPM_20150323_bookdata.txt
# Saved to data/WFC_20150323_bookdata.txt
# Saved to data/BAC_20150323_bookdata.txt
# Saved to data/HSBC_20150323_bookdata.txt
# Saved to data/C_20150323_bookdata.txt
# Saved to data/JNJ_20150323_bookdata.txt
# Saved to data/NVS_20150323_bookdata.txt
# Saved to data/PFE_20150323_bookdata.txt
# Saved to data/MRK_20150323_bookdata.txt
# Saved to data/UNH_20150323_bookdata.txt
# Saved to data/XOM_20150323_bookdata.txt
# Saved to data/GE_20150323_bookdata.txt
# Saved to data/CVX_20150323_bookdata.txt
# Saved to data/TOT_20150323_bookdata.txt
# Saved to data/PTR_20150323_bookdata.txt
# Saved to data/IVV_20150323_bookdata.txt
# 20150324
# DONDONDON: it's now 18:04:59.055636
# Saved to data/PG_20150324_bookdata.txt
# Saved to data/UN_20150324_bookdata.txt
# Saved to data/UL_20150324_bookdata.txt
# Saved to data/BHP_20150324_bookdata.txt
# Saved to data/DOW_20150324_bookdata.txt
# Saved to data/AAPL_20150324_bookdata.txt
# Saved to data/GOOG_20150324_bookdata.txt
# Saved to data/MSFT_20150324_bookdata.txt
# Saved to data/FB_20150324_bookdata.txt
# Saved to data/ORCL_20150324_bookdata.txt
# Saved to data/JPM_20150324_bookdata.txt
# Saved to data/WFC_20150324_bookdata.txt
# Saved to data/BAC_20150324_bookdata.txt
# Saved to data/HSBC_20150324_bookdata.txt
# Saved to data/C_20150324_bookdata.txt
# Saved to data/JNJ_20150324_bookdata.txt
# Saved to data/NVS_20150324_bookdata.txt
# Saved to data/PFE_20150324_bookdata.txt
# Saved to data/MRK_20150324_bookdata.txt
# Saved to data/UNH_20150324_bookdata.txt
# Saved to data/XOM_20150324_bookdata.txt
# Saved to data/GE_20150324_bookdata.txt
# Saved to data/CVX_20150324_bookdata.txt
# Saved to data/TOT_20150324_bookdata.txt
# Saved to data/PTR_20150324_bookdata.txt
# Saved to data/IVV_20150324_bookdata.txt
# 20150325
# DONDONDON: it's now 18:05:00.445642
# Saved to data/PG_20150325_bookdata.txt
# Saved to data/UN_20150325_bookdata.txt
# Saved to data/UL_20150325_bookdata.txt
# Saved to data/BHP_20150325_bookdata.txt
# Saved to data/DOW_20150325_bookdata.txt
# Saved to data/AAPL_20150325_bookdata.txt
# Saved to data/GOOG_20150325_bookdata.txt
# Saved to data/MSFT_20150325_bookdata.txt
# Saved to data/FB_20150325_bookdata.txt
# Saved to data/ORCL_20150325_bookdata.txt
# Saved to data/JPM_20150325_bookdata.txt
# Saved to data/WFC_20150325_bookdata.txt
# Saved to data/BAC_20150325_bookdata.txt
# Saved to data/HSBC_20150325_bookdata.txt
# Saved to data/C_20150325_bookdata.txt
# Saved to data/JNJ_20150325_bookdata.txt
# Saved to data/NVS_20150325_bookdata.txt
# Saved to data/PFE_20150325_bookdata.txt
# Saved to data/MRK_20150325_bookdata.txt
# Saved to data/UNH_20150325_bookdata.txt
# Saved to data/XOM_20150325_bookdata.txt
# Saved to data/GE_20150325_bookdata.txt
# Saved to data/CVX_20150325_bookdata.txt
# Saved to data/TOT_20150325_bookdata.txt
# Saved to data/PTR_20150325_bookdata.txt
# Saved to data/IVV_20150325_bookdata.txt
# 20150326
# DONDONDON: it's now 18:04:56.683801
# Saved to data/PG_20150326_bookdata.txt
# Saved to data/UN_20150326_bookdata.txt
# Saved to data/UL_20150326_bookdata.txt
# Saved to data/BHP_20150326_bookdata.txt
# Saved to data/DOW_20150326_bookdata.txt
# Saved to data/AAPL_20150326_bookdata.txt
# Saved to data/GOOG_20150326_bookdata.txt
# Saved to data/MSFT_20150326_bookdata.txt
# Saved to data/FB_20150326_bookdata.txt
# Saved to data/ORCL_20150326_bookdata.txt
# Saved to data/JPM_20150326_bookdata.txt
# Saved to data/WFC_20150326_bookdata.txt
# Saved to data/BAC_20150326_bookdata.txt
# Saved to data/HSBC_20150326_bookdata.txt
# Saved to data/C_20150326_bookdata.txt
# Saved to data/JNJ_20150326_bookdata.txt
# Saved to data/NVS_20150326_bookdata.txt
# Saved to data/PFE_20150326_bookdata.txt
# Saved to data/MRK_20150326_bookdata.txt
# Saved to data/UNH_20150326_bookdata.txt
# Saved to data/XOM_20150326_bookdata.txt
# Saved to data/GE_20150326_bookdata.txt
# Saved to data/CVX_20150326_bookdata.txt
# Saved to data/TOT_20150326_bookdata.txt
# Saved to data/PTR_20150326_bookdata.txt
# Saved to data/IVV_20150326_bookdata.txt
# 20150327
# DONDONDON: it's now 18:04:52.556226
# Saved to data/PG_20150327_bookdata.txt
# Saved to data/UN_20150327_bookdata.txt
# Saved to data/UL_20150327_bookdata.txt
# Saved to data/BHP_20150327_bookdata.txt
# Saved to data/DOW_20150327_bookdata.txt
# Saved to data/AAPL_20150327_bookdata.txt
# Saved to data/GOOG_20150327_bookdata.txt
# Saved to data/MSFT_20150327_bookdata.txt
# Saved to data/FB_20150327_bookdata.txt
# Saved to data/ORCL_20150327_bookdata.txt
# Saved to data/JPM_20150327_bookdata.txt
# Saved to data/WFC_20150327_bookdata.txt
# Saved to data/BAC_20150327_bookdata.txt
# Saved to data/HSBC_20150327_bookdata.txt
# Saved to data/C_20150327_bookdata.txt
# Saved to data/JNJ_20150327_bookdata.txt
# Saved to data/NVS_20150327_bookdata.txt
# Saved to data/PFE_20150327_bookdata.txt
# Saved to data/MRK_20150327_bookdata.txt
# Saved to data/UNH_20150327_bookdata.txt
# Saved to data/XOM_20150327_bookdata.txt
# Saved to data/GE_20150327_bookdata.txt
# Saved to data/CVX_20150327_bookdata.txt
# Saved to data/TOT_20150327_bookdata.txt
# Saved to data/PTR_20150327_bookdata.txt
# Saved to data/IVV_20150327_bookdata.txt
# 20150330
# DONDONDON: it's now 18:04:52.601588
# Saved to data/PG_20150330_bookdata.txt
# Saved to data/UN_20150330_bookdata.txt
# Saved to data/UL_20150330_bookdata.txt
# Saved to data/BHP_20150330_bookdata.txt
# Saved to data/DOW_20150330_bookdata.txt
# Saved to data/AAPL_20150330_bookdata.txt
# Saved to data/GOOG_20150330_bookdata.txt
# Saved to data/MSFT_20150330_bookdata.txt
# Saved to data/FB_20150330_bookdata.txt
# Saved to data/ORCL_20150330_bookdata.txt
# Saved to data/JPM_20150330_bookdata.txt
# Saved to data/WFC_20150330_bookdata.txt
# Saved to data/BAC_20150330_bookdata.txt
# Saved to data/HSBC_20150330_bookdata.txt
# Saved to data/C_20150330_bookdata.txt
# Saved to data/JNJ_20150330_bookdata.txt
# Saved to data/NVS_20150330_bookdata.txt
# Saved to data/PFE_20150330_bookdata.txt
# Saved to data/MRK_20150330_bookdata.txt
# Saved to data/UNH_20150330_bookdata.txt
# Saved to data/XOM_20150330_bookdata.txt
# Saved to data/GE_20150330_bookdata.txt
# Saved to data/CVX_20150330_bookdata.txt
# Saved to data/TOT_20150330_bookdata.txt
# Saved to data/PTR_20150330_bookdata.txt
# Saved to data/IVV_20150330_bookdata.txt
# 20150331
# DONDONDON: it's now 18:04:58.903768
# Saved to data/PG_20150331_bookdata.txt
# Saved to data/UN_20150331_bookdata.txt
# Saved to data/UL_20150331_bookdata.txt
# Saved to data/BHP_20150331_bookdata.txt
# Saved to data/DOW_20150331_bookdata.txt
# Saved to data/AAPL_20150331_bookdata.txt
# Saved to data/GOOG_20150331_bookdata.txt
# Saved to data/MSFT_20150331_bookdata.txt
# Saved to data/FB_20150331_bookdata.txt
# Saved to data/ORCL_20150331_bookdata.txt
# Saved to data/JPM_20150331_bookdata.txt
# Saved to data/WFC_20150331_bookdata.txt
# Saved to data/BAC_20150331_bookdata.txt
# Saved to data/HSBC_20150331_bookdata.txt
# Saved to data/C_20150331_bookdata.txt
# Saved to data/JNJ_20150331_bookdata.txt
# Saved to data/NVS_20150331_bookdata.txt
# Saved to data/PFE_20150331_bookdata.txt
# Saved to data/MRK_20150331_bookdata.txt
# Saved to data/UNH_20150331_bookdata.txt
# Saved to data/XOM_20150331_bookdata.txt
# Saved to data/GE_20150331_bookdata.txt
# Saved to data/CVX_20150331_bookdata.txt
# Saved to data/TOT_20150331_bookdata.txt
# Saved to data/PTR_20150331_bookdata.txt
# Saved to data/IVV_20150331_bookdata.txt
# 20150401
# DONDONDON: it's now 18:04:42.691213
# Saved to data/PG_20150401_bookdata.txt
# Saved to data/UN_20150401_bookdata.txt
# Saved to data/UL_20150401_bookdata.txt
# Saved to data/BHP_20150401_bookdata.txt
# Saved to data/DOW_20150401_bookdata.txt
# Saved to data/AAPL_20150401_bookdata.txt
# Saved to data/GOOG_20150401_bookdata.txt
# Saved to data/MSFT_20150401_bookdata.txt
# Saved to data/FB_20150401_bookdata.txt
# Saved to data/ORCL_20150401_bookdata.txt
# Saved to data/JPM_20150401_bookdata.txt
# Saved to data/WFC_20150401_bookdata.txt
# Saved to data/BAC_20150401_bookdata.txt
# Saved to data/HSBC_20150401_bookdata.txt
# Saved to data/C_20150401_bookdata.txt
# Saved to data/JNJ_20150401_bookdata.txt
# Saved to data/NVS_20150401_bookdata.txt
# Saved to data/PFE_20150401_bookdata.txt
# Saved to data/MRK_20150401_bookdata.txt
# Saved to data/UNH_20150401_bookdata.txt
# Saved to data/XOM_20150401_bookdata.txt
# Saved to data/GE_20150401_bookdata.txt
# Saved to data/CVX_20150401_bookdata.txt
# Saved to data/TOT_20150401_bookdata.txt
# Saved to data/PTR_20150401_bookdata.txt
# Saved to data/IVV_20150401_bookdata.txt
# 20150402
# DONDONDON: it's now 18:05:00.413488
# Saved to data/PG_20150402_bookdata.txt
# Saved to data/UN_20150402_bookdata.txt
# Saved to data/UL_20150402_bookdata.txt
# Saved to data/BHP_20150402_bookdata.txt
# Saved to data/DOW_20150402_bookdata.txt
# Saved to data/AAPL_20150402_bookdata.txt
# Saved to data/GOOG_20150402_bookdata.txt
# Saved to data/MSFT_20150402_bookdata.txt
# Saved to data/FB_20150402_bookdata.txt
# Saved to data/ORCL_20150402_bookdata.txt
# Saved to data/JPM_20150402_bookdata.txt
# Saved to data/WFC_20150402_bookdata.txt
# Saved to data/BAC_20150402_bookdata.txt
# Saved to data/HSBC_20150402_bookdata.txt
# Saved to data/C_20150402_bookdata.txt
# Saved to data/JNJ_20150402_bookdata.txt
# Saved to data/NVS_20150402_bookdata.txt
# Saved to data/PFE_20150402_bookdata.txt
# Saved to data/MRK_20150402_bookdata.txt
# Saved to data/UNH_20150402_bookdata.txt
# Saved to data/XOM_20150402_bookdata.txt
# Saved to data/GE_20150402_bookdata.txt
# Saved to data/CVX_20150402_bookdata.txt
# Saved to data/TOT_20150402_bookdata.txt
# Saved to data/PTR_20150402_bookdata.txt
# Saved to data/IVV_20150402_bookdata.txt
# 20150403
# 20150406
# DONDONDON: it's now 18:04:56.672877
# Saved to data/PG_20150406_bookdata.txt
# Saved to data/UN_20150406_bookdata.txt
# Saved to data/UL_20150406_bookdata.txt
# Saved to data/BHP_20150406_bookdata.txt
# Saved to data/DOW_20150406_bookdata.txt
# Saved to data/AAPL_20150406_bookdata.txt
# Saved to data/GOOG_20150406_bookdata.txt
# Saved to data/MSFT_20150406_bookdata.txt
# Saved to data/FB_20150406_bookdata.txt
# Saved to data/ORCL_20150406_bookdata.txt
# Saved to data/JPM_20150406_bookdata.txt
# Saved to data/WFC_20150406_bookdata.txt
# Saved to data/BAC_20150406_bookdata.txt
# Saved to data/HSBC_20150406_bookdata.txt
# Saved to data/C_20150406_bookdata.txt
# Saved to data/JNJ_20150406_bookdata.txt
# Saved to data/NVS_20150406_bookdata.txt
# Saved to data/PFE_20150406_bookdata.txt
# Saved to data/MRK_20150406_bookdata.txt
# Saved to data/UNH_20150406_bookdata.txt
# Saved to data/XOM_20150406_bookdata.txt
# Saved to data/GE_20150406_bookdata.txt
# Saved to data/CVX_20150406_bookdata.txt
# Saved to data/TOT_20150406_bookdata.txt
# Saved to data/PTR_20150406_bookdata.txt
# Saved to data/IVV_20150406_bookdata.txt
# 20150407
# DONDONDON: it's now 18:04:50.360704
# Saved to data/PG_20150407_bookdata.txt
# Saved to data/UN_20150407_bookdata.txt
# Saved to data/UL_20150407_bookdata.txt
# Saved to data/BHP_20150407_bookdata.txt
# Saved to data/DOW_20150407_bookdata.txt
# Saved to data/AAPL_20150407_bookdata.txt
# Saved to data/GOOG_20150407_bookdata.txt
# Saved to data/MSFT_20150407_bookdata.txt
# Saved to data/FB_20150407_bookdata.txt
# Saved to data/ORCL_20150407_bookdata.txt
# Saved to data/JPM_20150407_bookdata.txt
# Saved to data/WFC_20150407_bookdata.txt
# Saved to data/BAC_20150407_bookdata.txt
# Saved to data/HSBC_20150407_bookdata.txt
# Saved to data/C_20150407_bookdata.txt
# Saved to data/JNJ_20150407_bookdata.txt
# Saved to data/NVS_20150407_bookdata.txt
# Saved to data/PFE_20150407_bookdata.txt
# Saved to data/MRK_20150407_bookdata.txt
# Saved to data/UNH_20150407_bookdata.txt
# Saved to data/XOM_20150407_bookdata.txt
# Saved to data/GE_20150407_bookdata.txt
# Saved to data/CVX_20150407_bookdata.txt
# Saved to data/TOT_20150407_bookdata.txt
# Saved to data/PTR_20150407_bookdata.txt
# Saved to data/IVV_20150407_bookdata.txt
# 20150408
# DONDONDON: it's now 18:04:59.145191
# Saved to data/PG_20150408_bookdata.txt
# Saved to data/UN_20150408_bookdata.txt
# Saved to data/UL_20150408_bookdata.txt
# Saved to data/BHP_20150408_bookdata.txt
# Saved to data/DOW_20150408_bookdata.txt
# Saved to data/AAPL_20150408_bookdata.txt
# Saved to data/GOOG_20150408_bookdata.txt
# Saved to data/MSFT_20150408_bookdata.txt
# Saved to data/FB_20150408_bookdata.txt
# Saved to data/ORCL_20150408_bookdata.txt
# Saved to data/JPM_20150408_bookdata.txt
# Saved to data/WFC_20150408_bookdata.txt
# Saved to data/BAC_20150408_bookdata.txt
# Saved to data/HSBC_20150408_bookdata.txt
# Saved to data/C_20150408_bookdata.txt
# Saved to data/JNJ_20150408_bookdata.txt
# Saved to data/NVS_20150408_bookdata.txt
# Saved to data/PFE_20150408_bookdata.txt
# Saved to data/MRK_20150408_bookdata.txt
# Saved to data/UNH_20150408_bookdata.txt
# Saved to data/XOM_20150408_bookdata.txt
# Saved to data/GE_20150408_bookdata.txt
# Saved to data/CVX_20150408_bookdata.txt
# Saved to data/TOT_20150408_bookdata.txt
# Saved to data/PTR_20150408_bookdata.txt
# Saved to data/IVV_20150408_bookdata.txt
# 20150409
# DONDONDON: it's now 18:04:28.923059
# Saved to data/PG_20150409_bookdata.txt
# Saved to data/UN_20150409_bookdata.txt
# Saved to data/UL_20150409_bookdata.txt
# Saved to data/BHP_20150409_bookdata.txt
# Saved to data/DOW_20150409_bookdata.txt
# Saved to data/AAPL_20150409_bookdata.txt
# Saved to data/GOOG_20150409_bookdata.txt
# Saved to data/MSFT_20150409_bookdata.txt
# Saved to data/FB_20150409_bookdata.txt
# Saved to data/ORCL_20150409_bookdata.txt
# Saved to data/JPM_20150409_bookdata.txt
# Saved to data/WFC_20150409_bookdata.txt
# Saved to data/BAC_20150409_bookdata.txt
# Saved to data/HSBC_20150409_bookdata.txt
# Saved to data/C_20150409_bookdata.txt
# Saved to data/JNJ_20150409_bookdata.txt
# Saved to data/NVS_20150409_bookdata.txt
# Saved to data/PFE_20150409_bookdata.txt
# Saved to data/MRK_20150409_bookdata.txt
# Saved to data/UNH_20150409_bookdata.txt
# Saved to data/XOM_20150409_bookdata.txt
# Saved to data/GE_20150409_bookdata.txt
# Saved to data/CVX_20150409_bookdata.txt
# Saved to data/TOT_20150409_bookdata.txt
# Saved to data/PTR_20150409_bookdata.txt
# Saved to data/IVV_20150409_bookdata.txt
# 20150410
# DONDONDON: it's now 18:04:55.429444
# Saved to data/PG_20150410_bookdata.txt
# Saved to data/UN_20150410_bookdata.txt
# Saved to data/UL_20150410_bookdata.txt
# Saved to data/BHP_20150410_bookdata.txt
# Saved to data/DOW_20150410_bookdata.txt
# Saved to data/AAPL_20150410_bookdata.txt
# Saved to data/GOOG_20150410_bookdata.txt
# Saved to data/MSFT_20150410_bookdata.txt
# Saved to data/FB_20150410_bookdata.txt
# Saved to data/ORCL_20150410_bookdata.txt
# Saved to data/JPM_20150410_bookdata.txt
# Saved to data/WFC_20150410_bookdata.txt
# Saved to data/BAC_20150410_bookdata.txt
# Saved to data/HSBC_20150410_bookdata.txt
# Saved to data/C_20150410_bookdata.txt
# Saved to data/JNJ_20150410_bookdata.txt
# Saved to data/NVS_20150410_bookdata.txt
# Saved to data/PFE_20150410_bookdata.txt
# Saved to data/MRK_20150410_bookdata.txt
# Saved to data/UNH_20150410_bookdata.txt
# Saved to data/XOM_20150410_bookdata.txt
# Saved to data/GE_20150410_bookdata.txt
# Saved to data/CVX_20150410_bookdata.txt
# Saved to data/TOT_20150410_bookdata.txt
# Saved to data/PTR_20150410_bookdata.txt
# Saved to data/IVV_20150410_bookdata.txt

# %%
market = ["IVV"]
basic_large = ["PG", "UN", "UL", "BHP", "DOW"]
basic_mid = ["TECK", "FBHS", "SQM", "WPM", "SEE"]
tech_large = ["AAPL", "GOOG", "MSFT", "FB", "ORCL"]
tech_mid = ["IPG", "CDNS", "DOX", "VRSN", "FLEX"]
finance_large = ["JPM", "WFC", "BAC", "HSBC", "C"]
finance_mid = ["ATH", "CBOE", "WF", "ETFC", "AVAL"]
health_large = ["JNJ", "NVS", "PFE", "MRK", "UNH"]
health_mid = ["SGEN", "VAR", "TFX", "ALKS", "JAZZ"]
energy_large = ["XOM", "GE", "CVX", "TOT", "PTR"]
energy_mid = ["XEC", "TSO", "YPF", "EQT", "PE"]
symbols = market + basic_large + basic_mid + tech_large + tech_mid + finance_large + finance_mid + health_large + health_mid + energy_large + energy_mid
print symbols
# Out:
# ['IVV', 'PG', 'UN', 'UL', 'BHP', 'DOW', 'TECK', 'FBHS', 'SQM', 'WPM', 'SEE', 'AAPL', 'GOOG', 'MSFT', 'FB', 'ORCL', 'IPG', 'CDNS', 'DOX', 'VRSN', 'FLEX', 'JPM', 'WFC', 'BAC', 'HSBC', 'C', 'ATH', 'CBOE', 'WF', 'ETFC', 'AVAL', 'JNJ', 'NVS', 'PFE', 'MRK', 'UNH', 'SGEN', 'VAR', 'TFX', 'ALKS', 'JAZZ', 'XOM', 'GE', 'CVX', 'TOT', 'PTR', 'XEC', 'TSO', 'YPF', 'EQT', 'PE']
